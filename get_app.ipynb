# %%
import requests
import time
import csv
import sys
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

url = "https://www.getapp.com/business-intelligence-analytics-software/"
page = requests.get(url)
soup = BeautifulSoup(page.text,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.getapp.com/business-intelligence-analytics-software/" rel="canonical"/>
#   <link href="https://www.getapp.com/business-intelligence-analytics-software/?page=2" rel="next"/>
#   <link href="https://www.getapp.com/business-intelligence-analytics-software/" hreflang="en" rel="alternate"/>
#   <link href="https://www.getapp.de/directory/h47/business-intelligence-analytics/software" hreflang="de" rel="alternate"/>
#   <link href="https://www.getapp.fr/directory/h47/business-intelligence-analytics/software" hreflang="fr" rel="alternate"/>
#   <style type="text/css">
#    @font-face {
#   font-family: 'FontAwesome';
#   src: url('/assets/094ae6197a89e703115969f995f012aa/fonts/fontawesome-webfont.eot');
#   src: url('/assets/094ae6197a89e703115969f995f012aa/fonts/fontawesome-webfont.eot#iefix') format('embedded-opentype'), url('/assets/094ae6197a89e703115969f995f012aa/fonts/fontawesome-webfont.woff2') format('woff2'), url('/assets/094ae6197a89e703115969f995f012aa/fonts/fontawesome-webfont.woff') format('woff'), url('/assets/094ae6197a89e703115969f995f012aa/fonts/fontawesome-webfont.ttf') format('truetype'), url('/assets/094ae6197a89e703115969f995f012aa/fonts/fontawesome-webfont.svg#fontawesomeregular') format('svg');
#   font-weight: normal;
#   font-style: normal;
# }
#   </style>
#   <link href="/assets/094ae6197a89e703115969f995f012aa/css/getapp.css" rel="stylesheet"/>
#   <!-- SVG icons from Font Awesome - https://fontawesome.com/license -->
#   <script type="text/javascript">
#    window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(16),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(17),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(v,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(v,function(t,n){i(w,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(v,function(t,n){i(w,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(19)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(19)(r);n.exports=r,o.inPlace(window.history,["pushState","replaceState"], ...
# ;NREUM.info={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",licenseKey:"bd6ef6ec05",applicationID:"3996346",sa:1}
#   </script>
#   <!--[if lt IE 9]><script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script><![endif]-->
#   <script type="text/javascript">
#    function rc(n){var nameEQ=n+"=";var ca=document.cookie.split(';');for(var i=0;i<ca.length;i++){var c=ca[i];while(c.charAt(0)==' ')c=c.substring(1,c.length);if(c.indexOf(nameEQ)==0)return c.substring(nameEQ.length,c.length)}return null}
# function cc(n,v,d){if(d){var date=new Date();date.setTime(date.getTime()+(d*24*60*60*1000));var e="; expires="+date.toGMTString()}else var e="";document.cookie=n+"="+v+e+"; path=/"}
# function gapctrnd(){try{var uu32=new Uint32Array(1);return crypto.getRandomValues(uu32)[0];}catch(e){return Math.round(Math.random()*0x7FFFFFFF)}}
# function gengapct(){return [gapctrnd(),Math.round((new Date).getTime()/1E3)].join('.')}
# var h;
# if(document.cookie.indexOf('gapct')>=0){h=rc('gapct')}
# else if(document.cookie.indexOf('_ga')>=0){h=rc('_ga').split('.').slice(2,4).join('.')}
# else{h=gengapct()}
# cc('gapct',h,730);
#   </script>
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[] ;w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l ='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl+ '&gtm_auth=kpTycchMTc363wxje_RihQ&gtm_preview=env-2&gtm_cookies_win=x';f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-PTKM3XM');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Hotjar -->
#   <script>
#    (function(h,o,t,j,a,r){ h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)}; h._hjSettings={hjid:491299,hjsv:5}; a=o.getElementsByTagName('head')[0]; r=o.createElement('script');r.async=1; r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv; a.appendChild(r); })(window,document,'//static.hotjar.com/c/hotjar-','.js?sv=');
#   </script>
#   <!-- End Hotjar -->
#   <script type="text/javascript">
#    var opts = { 'siteSpeedSampleRate': 100 };
# var gapct = rc('gapct');
# if(gapct) { opts['clientId'] = gapct; }
# ga('create', "UA-11773596-1", 'auto', opts);
# if(!gapct) {
#   ga(function(tracker) {
#     var clientId = tracker.get('clientId');
#     cc('gapct', clientId, 730);
#   });
# }
# ga('require', 'displayfeatures');
# ga('set', 'contentGroup3', "serp_header");
#
#
# ga('set', 'dimension22', "false");
# ga('set', 'dimension11', "serp_header");
# ga('set', 'dimension3', "0");
# ga('set', 'metric2', 20190117);
# ga('set', 'metric3', 25);
# ga('set', 'metric4', 25);
# ga('set', 'metric5', 0);
# ga('set', 'metric1', 20120810);
#
#
#
#
# (function(hash) {
#   if(hash.indexOf('#q=') == 0) {
#     var path = location.pathname;
#     if(typeof location.search == 'string') {
#       path += location.search;
#       path += ~location.search.indexOf('?') ? '&' : '?'
#     } else {
#       path += '?';
#     }
#     path += hash.substring(1);
#     ga('send', 'pageview', path);
#   } else {
#     ga('send', 'pageview', location.pathname + location.search + location.hash);
#   }
#   setTimeout(function() {
#     ga('send', 'event', 'time', '11 seconds', "ua_serp_header", { nonInteraction: true });
#   }, 11000);
# })(String(window.location.hash));
#   </script>
#   <script>
#    /*!
#   * domready (c) Dustin Diaz 2014 - License MIT
#   */
# !function (name, definition) {
#
#   if (typeof module != 'undefined') module.exports = definition()
#   else if (typeof define == 'function' && typeof define.amd == 'object') define(definition)
#   else this[name] = definition()
#
# }('domready', function () {
#
#   var fns = [], listener
#     , doc = document
#     , hack = doc.documentElement.doScroll
#     , domContentLoaded = 'DOMContentLoaded'
#     , loaded = (hack ? /^loaded|^c/ : /^loaded|^i|^c/).test(doc.readyState)
#
#
#   if (!loaded)
#   doc.addEventListener(domContentLoaded, listener = function () {
#     doc.removeEventListener(domContentLoaded, listener)
#     loaded = 1
#     while (listener = fns.shift()) listener()
#   })
#
#   return function (fn) {
#     loaded ? setTimeout(fn, 0) : fns.push(fn)
#   }
#
# });
#   </script>
#   <meta content="DPR, Viewport-Width, Width" http-equiv="Accept-CH"/>
#   <style type="text/css">
#    .img-fluid, .img-fluid-lazy {
#   position: relative;
#   width: 100%;
#   top: 0;
#   left: 0;
#   display: block;
#   color: #fff;
# }
#
# .img-fluid-fill-height {
#   position: relative;
#   width: 100%;
#   height: 100%;
#   top: 0;
#   left: 0;
#   display: block;
#   color: #fff;
# }
#   </style>
#   <script>
#    (function(i, s, o, d, r, a, m) {
#   i['ElrondTrackingObject'] = r;
#   i[r] = i[r] || function() {
#     (i[r].q = i[r].q || []).push(arguments)
#   }, i[r].l = 1 * new Date();
#   i[r].d = d;
#   a = s.createElement(o);
#   m = s.getElementsByTagName(o)[0];
#   a.async = 1;
#   a.src = d;
#   m.parentNode.insertBefore(a, m)
# })(window, document, 'script', 'https://elrond.gappdev.com/webpack/tracker.js', 'et');
# et('site_key', 'a5faecc8524c8d2561bf82a5e82b52c4');
# et('visitor_key', '0A8410AC93C1405C0A41D3970228E1B4');
# et('test', 'false');
# var elrondEvents = [{"action":"header_view","subject":47}];
# var elrondEventsLength = elrondEvents.length;
# for (var i = 0; i < elrondEventsLength; i++) {
#   et(elrondEvents[i]['action'], {subject: {id: elrondEvents[i]['subject']}});
# }
#   </script>
#   <title>
#    #1 Business Intelligence &amp; Analytics Software &amp; Best Application Comparison | GetApp®
#   </title>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.getapp.com/business-intelligence-analytics-software/" property="og:url"/>
#   <meta content="GetApp" property="og:site_name"/>
#   <meta content="https://www.getapp.com/i/og_logo.png" property="og:image"/>
#   <meta content="#1 Business Intelligence &amp; Analytics Software &amp; Best Application Comparison" property="og:title"/>
#   <meta content="https://www.getapp.com/i/og_logo.png" itemprop="image"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="https://www.getapp.com/business-intelligence-analytics-software/" name="twitter:url"/>
#   <meta content="#1 Business Intelligence &amp; Analytics Software &amp; Best Application Comparison" name="twitter:title"/>
#   <meta content="https://www.getapp.com/i/og_logo.png" name="twitter:image"/>
#   <meta content="@GetApp" name="twitter:site"/>
#   <meta content="Search a portfolio of Business Intelligence &amp;amp; Analytics Software, SaaS and Cloud Applications. GetApp is your free Directory to Compare, Short-list and Evaluate Business Solutions. Save time with reviews, on-line decision support and guides." property="og:description"/>
#   <meta content="Search a portfolio of Business Intelligence &amp;amp; Analytics Software, SaaS and Cloud Applications. GetApp is your free Directory to Compare, Short-list and Evaluate Business Solutions. Save time with reviews, on-line decision support and guides." name="twitter:description"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script>
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"bd6ef6ec05","applicationID":"3996346","transactionName":"dFhYFxRWWA4HSxdnXFlWQhEHFnkDEFJdQEVbVlUGSX5xNkIWAkdZQlAbEAlfQBUDS10b","queueTime":0,"applicationTime":162,"agent":""}
#   </script>
#   <script>
#    (window.NREUM||(NREUM={})).loader_config={xpid:"UQ4BVlZACwoJUlJWAQ=="};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&&console.log(t)}catch(n){}}var o,i=t("ee"),a=t(16),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,o.indexOf("dev")!==-1&&(s.dev=!0),o.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&i.on("internal-error",function(t){r(t.stack)}),s.dev&&i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(17),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(8),t(7),"addEventListener"in window&&t(5),c.xhrWrappable&&t(9),d=!0)}s.on("fn-start",function(t,n,e){d&&(p+=1)}),s.on("fn-err",function(t,n,e){d&&!e[l]&&(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&&(this.bstStart=g.now())}),o.on(v,function(t,n){var e=t[0];e instanceof b&&i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(v,function(t,n){i(w,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(v,function(t,n){i(w,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&&!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&&o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(19)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&&(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n={object:t,"function":e}[typeof e];return n?s(n,"fn-",null,n.name||"anonymous"):e});this.wrapped=t[1]=r}),a.on(d+"-start",function(t){t[1]=this.wrapped||t[1]})},{}],6:[function(t,n,e){var r=t("ee").get("history"),o=t(19 ...
#   </script>
#   <meta content="True" name="HandheldFriendly"/>
#   <meta content="320" name="MobileOptimized"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="telephone=no, email=no" name="format-detection"/>
#   <meta content="no" name="apple-mobile-web-app-capable"/>
#   <meta content="unsafe-url" name="referrer"/>
#   <meta content="#689F38" name="theme-color"/>
#   <meta content="xdlm2WN0YLbRHfdvGBabqLjeb9Akv0XT2WhXaBeaWZU" name="google-site-verification"/>
#   <meta content="F982D3BE475FCD2842ACB655B1E89582" name="msvalidate.01"/>
#   <meta content="Search a portfolio of Business Intelligence &amp;amp; Analytics Software, SaaS and Cloud Applications. GetApp is your free Directory to Compare, Short-list and Evaluate Business Solutions. Save time with reviews, on-line decision support and guides." name="description"/>
#  </head>
#  <body id="top-apps">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PTKM3XM&amp;gtm_auth=kpTycchMTc363wxje_RihQ&amp;gtm_preview=env-2&amp;gtm_cookies_win=x" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div id="mask">
#   </div>
#   <div id="cookie_consent">
#    <div class="hidden-xs">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-12 col-md-12 col-sm-12">
#        <a class="pull-right" href="#" id="cookie_consent_approved">
#         <i class="fa fa-times-circle">
#         </i>
#         Close
#        </a>
#        <p>
#         We use cookies to deliver the best possible experience on our website. By accessing our website, you agree to our
#         <a href="/privacy_policy" style="text-decoration:underline">
#          Privacy Policy
#         </a>
#         and
#         <a href="/terms_of_use" style="text-decoration:underline">
#          General User Terms
#         </a>
#         .
#        </p>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="visible-xs" id="cookie-consent-xs">
#     We use cookies to deliver the best possible experience on our website. By accessing our website, you agree to our
#     <a href="/privacy_policy" style="text-decoration:underline">
#      Privacy Policy
#     </a>
#     and
#     <a href="/terms_of_use" style="text-decoration:underline">
#      General User Terms
#     </a>
#     .
#    </div>
#   </div>
#   <header>
#    <div class="container">
#     <div class="hidden-lg hidden-md hidden-sm hidden" id="mobile-search-overlay">
#      <a class="fa fa-times-circle" id="mobile-search-clear">
#      </a>
#      <div id="mobile-search-header">
#       <a href="#" id="mobile-search-back">
#        <i class="fa fa-chevron-left">
#        </i>
#       </a>
#       <form action="/search" class="form-inline" id="mobile-search-form">
#        <div class="form-group">
#         <input aria-autocomplete="both" aria-haspopup="false" autocapitalize="off" autocomplete="off" autocorrect="off" class="form-control search" dir="ltr" id="mobile-search" maxlength="100" name="query" placeholder="Search business apps" role="combobox" spellcheck="false" tabindex="1" type="search" value=""/>
#         <div class="invisible">
#          <input tabindex="-1" type="submit"/>
#         </div>
#        </div>
#       </form>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-sm-4 col-xs-8 col-lg-2 col-md-2">
#       <div class="visible-sm visible-xs mobile_nav">
#        <a class="expand_nav" data-tab-id="apps" href="#">
#         <i class="fa fa-bars">
#         </i>
#        </a>
#       </div>
#       <a class="navbar-brand" href="/">
#        <div class="hidden-xs">
#         <img alt="GetApp logo" class="img-responsive" src="/i/lowgow.png"/>
#        </div>
#        <div class="visible-xs">
#         <img alt="GetApp logo" class="img-responsive" src="/i/logo.svg"/>
#        </div>
#       </a>
#      </div>
#      <div class="col-sm-6 hidden-xs col-lg-5 col-md-6" id="header-search">
#       <form action="/search" class="search-header">
#        <i class="fa fa-search icon-search icon-search-yeah">
#        </i>
#        <input autocomplete="off" class="form-control search" id="appendedInputButton" maxlength="100" name="query" placeholder="Search business apps" type="text"/>
#        <div class="invisible">
#         <input tabindex="-1" type="submit"/>
#        </div>
#       </form>
#      </div>
#      <div class="col-sm-2 col-xs-4 links-block col-lg-5 col-md-4">
#       <div class="text-right">
#        <div class="visible-xs">
#         <a class="fa fa-search" id="mobile-search-icon">
#         </a>
#        </div>
#        <div class="hidden-xs">
#         <a class="evnt" data-evac="browse" data-evca="top_nav" data-evla="ua_serp_header" href="/browse">
#          Browse
#         </a>
#         <a class="hidden-sm hidden-md evnt" data-evac="top_apps" data-evca="top_nav" data-evla="ua_serp_header" href="/top-apps">
#          Top Apps
#         </a>
#         <a class="hidden-sm hidden-md evnt" data-evac="blog" data-evca="top_nav" data-evla="ua_serp_header" href="/blog/">
#          Blog
#         </a>
#         <a class="hidden-sm sign-in-link evnt" data-evac="sign_in" data-evca="top_nav" data-evla="ua_serp_header" href="#">
#          Sign in
#         </a>
#         <a class="hidden-sm evnt btn" data-evac="sign_out" data-evca="top_nav" data-evla="ua_serp_header" href="/join" id="join" style="margin-left: 20px;">
#          Join
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </header>
#   <a name="top">
#   </a>
#   <div id="secondary-header">
#    <div class="container">
#     <div class="navigation-row hscroll">
#      <ul class="evnt-scope breadcrumb">
#       <li>
#        <a class="evnt" data-evac="ua_top_nav" data-evca="ua_click_home" data-evla="ua_serp_header" href="/">
#         Home
#        </a>
#       </li>
#       <li itemscope="itemscope" itemtype="http://data-vocabulary.org/Breadcrumb">
#        <a href="/business-intelligence-analytics-software/" itemprop="url">
#         <span itemprop="title">
#          Business Intelligence &amp; Analytics Software
#         </span>
#        </a>
#       </li>
#      </ul>
#      <span class="why-getapp-is-free hidden-xs">
#       <a class="evnt" data-evac="ua_why_getapp_is_free" data-evca="ua_click" data-evla="ua_serp_header" data-target="#why-getapp-is-free" data-toggle="modal" href="#">
#        <i class="fa fa-info-circle">
#        </i>
#        <span class="hidden-xs">
#         Learn why GetApp is free
#        </span>
#       </a>
#      </span>
#     </div>
#     <div class="page-title-row hscroll">
#      <h1>
#       Business Intelligence &amp; Analytics Software
#      </h1>
#     </div>
#     <div class="hidden-sm hidden-xs">
#      <div class="section-description-row" style="margin-top:-5px;">
#       Best Comparison List of Vendor Applications &amp; Tools
#      </div>
#     </div>
#    </div>
#   </div>
#   <nav id="good">
#    <div class="container">
#     <div class="secondary-navigation-row hscroll">
#      <ul class="nav-links" role="tablist">
#       <li class="active">
#        <a href="/business-intelligence-analytics-software/">
#         All Apps
#        </a>
#       </li>
#       <li>
#        <a href="/business-intelligence-analytics-software/articles/">
#         Articles
#        </a>
#       </li>
#      </ul>
#      <div class="clearfix">
#      </div>
#     </div>
#    </div>
#   </nav>
#   <div class="container">
#    <div class="row">
#     <div class="col-lg-3 col-md-3">
#      <div id="sticky-width">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="yield">
#    <style type="text/css">
#     #getrank, #research, #guide {
#   margin-top: -1000px;
#   padding-top: 1000px;
# }
#
# #basket-wrap {
#   position:fixed;
#   bottom:0;
#   padding-left: 0px;
#   padding-right: 30px;
#   z-index: 4;
# }
#
# .compare-basket {
#   background: #fff;
#   border-radius: 2px;
#   display: block;
#   overflow: hidden;
#   box-shadow:0 1px 4px rgba(0,0,0,.12),0 1px 4px rgba(0,0,0,.12);
#   height: 110px;
# }
#
# .compare-basket .img-wrap {
#   margin-top: 12px;
#   box-sizing: border-box;
#   height: 65px;
#   width: 65px;
#   border: 1px solid #DDDDDD;
#   border-radius: 2px;
#   background-color: #FFFFFF;
# }
#
# img.listing-logo {
#   width: 64px;
# }
#
# .compare-basket .items {
#   display: flex;
#   padding-top: 15px;
# }
#
# @media (min-width: 768px) and (max-width: 991px) {
#   .compare-basket .items { margin-left: 15px; }
#   .compare-items { padding-left: 0; }
#   .remove-items {
#     padding-left: 0;
#     margin-left: -15px;
#   }
# }
#
# .compare-basket .item {
#   width: 74px;
#   height: 75px;
#   position: relative;
#   margin-right: 15px;
# }
#
# .compare-basket .remove_button {
#   position: absolute;
#   top: -12px;
#   right: 0px;
# }
# .compare-basket a.remove_button:hover {
#   cursor:pointer;
# }
#
# .compare-basket .compare_now {
#   margin-top: 40px;
# }
#
# .compare-basket .remove_all {
#   margin-top: 40px;
#   margin-left: 15px;
# }
#
# i.fa-minus {
#   background: #FD9E83;
#   color: #FFF !important;
#   font-size: 15px;
#   border-radius: 69px;
#   padding: 3px 4px;
# }
#    </style>
#    <div class="container evnt-scope">
#     <style type="text/css">
#      .card {
#   margin-bottom: 30px;
#   padding: 15px;
#   background: #fff;
# }
# .card h2 {
#   font-size: 24px;
#   line-height: 28px;
#   font-weight: 600;
#   letter-spacing: 0.33px;
# }
# .card hr {
#   margin-left: -15px;
#   margin-right: -15px;
# }
# .card p {
#   font-size: 16px;
#   line-height: 25px;
#   letter-spacing: -0.32px;
# }
#
# .btn.btn-text {
#   color: #689f38;
#   box-shadow: none;
#   padding: 8px 0 0 0;
#   margin: 10px 0 10px 0;
#   line-height: 16px;
#   text-transform: uppercase;
# }
#
# .btn-text:hover,
# .btn-text:active,
# .btn-text:focus {
#   color: #689f38;
#   box-shadow: none;
# }
#
# .box { margin-top: 30px; }
#
# .anchor {
#   display: block;
#   height: 97px;
#   margin-top: -97px;
#   visibility: hidden;
# }
#
# .legend {
#   margin-top: 10px;
#   margin-bottom: 20px;
#   text-align: center;
#   font-style: italic;
# }
#     </style>
#     <div class="row">
#      <div class="col-lg-12 col-md-12 col-sm-12 col-xs-12">
#       <div class="card">
#        <h2>
#         Everything you need to know
#        </h2>
#        <hr/>
#        <p>
#         This buyers guide will help you understand the key features of business intelligence and analytics (BI) software, its benefits and challenges, information on who uses BI software, and industry trends.
#        </p>
#        <a class="btn btn-text" href="#read-full-report">
#         Read the full report
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="tab-content" id="tabs">
#      <div class="tab-pane active" id="apps">
#       <div class="row">
#        <div class="col-lg-3 col-md-3 hidden-sm hidden-xs page_navigation">
#         <form class="facets">
#          <h6>
#           Categories
#          </h6>
#          <ul class="nav nav-pills nav-stacked top-links facet-category-links">
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/analytics/">
#             Analytics
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/big-data/">
#             Big Data
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/business-intelligence/">
#             Business Intelligence (BI)
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/reporting-dashboard/">
#             Dashboard
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/data-analysis/">
#             Data Analysis
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/data-analytics/">
#             Data Analytics
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/data-discovery/">
#             Data Discovery
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/data-extraction/">
#             Data Extraction
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/data-mining/">
#             Data Mining
#            </a>
#           </li>
#           <li>
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/data-quality/">
#             Data Quality
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/data-visualization/">
#             Data Visualization
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/gis/">
#             GIS
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/heatmap/">
#             Heatmap
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/location-intelligence/">
#             Location Intelligence
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/mobile-analytics/">
#             Mobile Analytics
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/predictive-analytics/">
#             Predictive Analytics
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/qualitative-data-analysis/">
#             Qualitative Data Analysis
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/analytics-reporting/">
#             Reporting
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/text-mining/">
#             Text Mining
#            </a>
#           </li>
#           <li class="hidden">
#            <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_categories" data-evla="ua_serp" href="/business-intelligence-analytics-software/web-analytics/">
#             Web Analytics
#            </a>
#           </li>
#           <li>
#            <a class="show-all" href="#">
#             + Show all
#            </a>
#           </li>
#          </ul>
#          <input name="sort" type="hidden" value="relevance"/>
#          <div class="row">
#           <div class="col-sm-12 col-xs-12 col-md-12 col-lg-12">
#            <h6>
#             Pricing model
#            </h6>
#            <ul class="nav nav-pills nav-stacked top-links">
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_pricingcategories_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/p/free/">
#               <div class="check">
#               </div>
#               Free
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_pricingcategories_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/p/free-trial/">
#               <div class="check">
#               </div>
#               Free Trial
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_pricingcategories_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/p/one-time-license/">
#               <div class="check">
#               </div>
#               One Time License
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_pricingcategories_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/p/open-source/">
#               <div class="check">
#               </div>
#               Open Source
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_pricingcategories_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/p/subscription/">
#               <div class="check">
#               </div>
#               Subscription
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix visible-xs-block">
#           </div>
#           <div class="col-sm-12 col-xs-12 col-md-12 col-lg-12">
#            <h6>
#             Devices supported
#            </h6>
#            <ul class="nav nav-pills nav-stacked top-links">
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_oses_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/os/android/">
#               <div class="check">
#               </div>
#               Android
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_oses_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/os/ipad/">
#               <div class="check">
#               </div>
#               iPad
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_oses_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/os/iphone/">
#               <div class="check">
#               </div>
#               iPhone
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_oses_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/os/web-based/">
#               <div class="check">
#               </div>
#               Web-based
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="clearfix visible-sm-block visible-xs-block">
#           </div>
#           <div class="col-sm-12 col-xs-12 col-md-12 col-lg-12">
#            <h6>
#             Avg. User Review
#            </h6>
#            <ul class="nav nav-pills nav-stacked top-links">
#             <li>
#              <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_rating_stars_ge" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/?rating_stars_ge=4&amp;sort=relevance">
#               <div class="rating" style="height:auto;">
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#               </div>
#               &amp; Up
#              </a>
#             </li>
#             <li>
#              <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_rating_stars_ge" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/?rating_stars_ge=3&amp;sort=relevance">
#               <div class="rating" style="height:auto;">
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#               </div>
#               &amp; Up
#              </a>
#             </li>
#             <li>
#              <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_rating_stars_ge" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/?rating_stars_ge=2&amp;sort=relevance">
#               <div class="rating" style="height:auto;">
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#               </div>
#               &amp; Up
#              </a>
#             </li>
#             <li>
#              <a class="evnt" data-evac="ua_facet" data-evca="ua_facet_rating_stars_ge" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/?rating_stars_ge=1&amp;sort=relevance">
#               <div class="rating" style="height:auto;">
#                <i class="fa fa-star">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#                <i class="fa fa-star-o">
#                </i>
#               </div>
#               &amp; Up
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-sm-12 col-xs-12 col-md-12 col-lg-12">
#            <h6>
#             Organization types
#            </h6>
#            <ul class="nav nav-pills nav-stacked top-links">
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_typecustomers_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/org/freelancers/">
#               <div class="check">
#               </div>
#               Freelancers
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_typecustomers_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/org/large-enterprises/">
#               <div class="check">
#               </div>
#               Large Enterprises
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_typecustomers_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/org/mid-size-business/">
#               <div class="check">
#               </div>
#               Mid Size Business
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_typecustomers_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/org/non-profits/">
#               <div class="check">
#               </div>
#               Non Profits
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_typecustomers_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/org/public-administrations/">
#               <div class="check">
#               </div>
#               Public Administrations
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_typecustomers_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/org/small-business/">
#               <div class="check">
#               </div>
#               Small Business
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="col-sm-12 col-xs-12 col-md-12 col-lg-12">
#            <h6>
#             Geographies served
#            </h6>
#            <ul class="nav nav-pills nav-stacked top-links">
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/asia/">
#               <div class="check">
#               </div>
#               Asia
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/australia/">
#               <div class="check">
#               </div>
#               Australia
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/brazil/">
#               <div class="check">
#               </div>
#               Brazil
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/canada/">
#               <div class="check">
#               </div>
#               Canada
#              </a>
#             </li>
#             <li>
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/china/">
#               <div class="check">
#               </div>
#               China
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/europe/">
#               <div class="check">
#               </div>
#               Europe
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/germany/">
#               <div class="check">
#               </div>
#               Germany
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/india/">
#               <div class="check">
#               </div>
#               India
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/japan/">
#               <div class="check">
#               </div>
#               Japan
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/latin-america/">
#               <div class="check">
#               </div>
#               Latin America
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/mexico/">
#               <div class="check">
#               </div>
#               Mexico
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/middle-east-and-africa/">
#               <div class="check">
#               </div>
#               Middle-East and Africa
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/united-kingdom/">
#               <div class="check">
#               </div>
#               United Kingdom
#              </a>
#             </li>
#             <li class="hidden">
#              <a class="paper-checkbox evnt" data-evac="ua_facet" data-evca="ua_facet_geographies_slug" data-evla="ua_serp_header" href="/business-intelligence-analytics-software/geo/united-states/">
#               <div class="check">
#               </div>
#               United States
#              </a>
#             </li>
#             <li>
#              <a class="show-all" href="#">
#               + Show more
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="hidden-sm hidden-xs">
#            <div class="col-sm-12 col-xs-12 col-md-12 col-lg-12">
#             <h6>
#              Integrated with
#             </h6>
#             <div style="margin-top:15px;">
#             </div>
#             <select class="form-control chosen" name="integrated_with_slug">
#              <option value="">
#               Select an app
#              </option>
#              <option value="act-on">
#               Act-On
#              </option>
#              <option value="activecampaign-email-marketing">
#               ActiveCampaign
#              </option>
#              <option value="adroll">
#               AdRoll
#              </option>
#              <option value="apiant">
#               APIANT
#              </option>
#              <option value="asana">
#               Asana
#              </option>
#              <option value="astronomer">
#               Astronomer
#              </option>
#              <option value="basecamp">
#               Basecamp
#              </option>
#              <option value="beckon">
#               Beckon
#              </option>
#              <option value="bigcommerce">
#               BigCommerce
#              </option>
#              <option value="bitium">
#               Bitium
#              </option>
#              <option value="box">
#               Box
#              </option>
#              <option value="braintree">
#               Braintree
#              </option>
# ...
#         </a>
#        </li>
#        <li>
#         <a class="follow-facebook" href="https://www.facebook.com/GetAppcom" rel="noopener" target="_blank" title="Follow us on Facebook">
#          <i aria-hidden="true" class="fa fa-facebook-official">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a class="follow-instagram" href="https://www.instagram.com/getappcom/" rel="noopener" target="_blank" title="Follow us on Instagram">
#          <i aria-hidden="true" class="fa fa-instagram">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a class="subscribe-youtube" href="https://www.youtube.com/c/GetAppCom" rel="noopener" target="_blank" title="Subscribe on YouTube">
#          <i aria-hidden="true" class="fa fa-youtube-play">
#          </i>
#         </a>
#        </li>
#        <li>
#         <a class="follow-google" href="https://plus.google.com/+GetAppCom" rel="publisher noopener" target="_blank" title="Follow us on Google+">
#          <i aria-hidden="true" class="fa fa-google-plus">
#          </i>
#         </a>
#        </li>
#       </ul>
#       <p>
#        <a class="text-muted evnt" data-evac="back_to_top" data-evca="ua_click" data-evla="ua_serp_header" href="#top">
#         <i class="fa fa-arrow-up">
#         </i>
#         Back to top
#        </a>
#       </p>
#      </div>
#     </div>
#     <div class="row legal">
#      <div class="col-xs-12">
#       <p class="text-muted">
#        © 2019 GetApp. All Rights Reserved.
#        <br/>
#        GetApp® is a registered trademark of Nubera eBusiness S.L.
#        <a href="/terms_of_use">
#         Terms of Use
#        </a>
#        |
#        <a href="/privacy_policy">
#         Privacy Policy
#        </a>
#       </p>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div id="default-nav">
#    <div class="page_navigation hidden-sm hidden-xs hidden-lg hidden-md">
#     <div class="facets">
#      <ul class="nav nav-pills nav-stacked">
#       <li>
#        <a href="/">
#         Home
#        </a>
#       </li>
#       <li>
#        <a href="/browse">
#         Browse
#        </a>
#       </li>
#       <li>
#        <a href="/top-apps">
#         Top Apps
#        </a>
#       </li>
#       <li>
#        <a href="/blog/">
#         Blog
#        </a>
#       </li>
#       <li class="divider">
#       </li>
#       <li>
#        <a class="sign-in-link" href="#">
#         Sign in
#        </a>
#       </li>
#       <li>
#        <a href="/join">
#         Join
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#   </div>
#   <div itemscope="" itemtype="http://schema.org/WebSite">
#    <meta content="GetApp" itemprop="name"/>
#    <meta content="https://www.getapp.com/" itemprop="url"/>
#    <form class="hide" itemprop="potentialAction" itemscope="" itemtype="http://schema.org/SearchAction">
#     <meta content="https://www.getapp.com/search?query={query}" itemprop="target"/>
#     <input itemprop="query-input" name="query" required="" type="text"/>
#     <input type="submit"/>
#    </form>
#   </div>
#   <script src="/assets/8fdff9a9a83e12c444cbe90270c3353c/js/mkt.js">
#   </script>
#   <script>
#    function imgixTrigger() {
#   imgix.fluid({
#     fluidClass: 'img-fluid',
#     updateOnResizeDown: true,
#     pixelStep: 5,
#     autoInsertCSSBestPractices: true,
#     lazyLoad: false
#   });
#
#   imgix.fluid({
#     fluidClass: 'img-fluid-lazy',
#     updateOnResizeDown: true,
#     pixelStep: 5,
#     autoInsertCSSBestPractices: true,
#     lazyLoad: true,
#     lazyLoadOffsetVertical: 600,
#     lazyLoadOffsetHorizontal: 600
#   });
#
#   imgix.fluid({
#     fluidClass: 'img-fluid-fill-height',
#     updateOnResizeDown: true,
#     pixelStep: 5,
#     autoInsertCSSBestPractices: true,
#     fitImgTagToContainerHeight: true
#   });
# }
# imgix.onready(imgixTrigger);
#   </script>
#   <div class="modal why-getapp-is-free-modal fade" id="why-getapp-is-free" role="dialog" tabindex="-1">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         <i class="fa fa-times-circle-o">
#         </i>
#        </span>
#       </button>
#       <h4 class="modal-title">
#        Why GetApp is Free
#       </h4>
#      </div>
#      <div class="modal-body">
#       <div class="container-fluid">
#        <div class="row">
#         <p>
#          GetApp offers free software discovery and selection resources for professionals like you. Our service is free because software vendors pay us when they generate web traffic and sales leads from GetApp users.
#         </p>
#         <p>
#          Because we’re committed to help you find the right solution for your business needs, we list all software vendors on our website, and give them the opportunity to feature their solutions and collect user reviews.
#         </p>
#         <p>
#          At GetApp, our comprehensive software listings, verified user reviews, product comparison pages, articles and AppFinder, our assistive tool, will empower you to make confident and well-informed purchase decisions.
#         </p>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script>
#    var navbarHeight = 50;
#
# domready(function() {
#   $(function() {
#     $(document).on('focus', '#appendedInputButton', function() {
#       ga('send', 'event', 'ua_focus', 'ua_search', 'ua_serp_header');
#     });
#   });
#
#   $('.sign-in-link').click(function(){
#     (new LoginModal({source: 'header', onboarding: true})).render();
#   });
#   $('.nav-links').stickyTabs({ backToTop: true });
#
#   var t = $('header').innerHeight() + $('nav#good').innerHeight() + 26;
#   var b = $('footer').innerHeight();
#   $('nav#good').sticky({ topSpacing: window.innerWidth > 767 ? navbarHeight : 0, className: 'stuck' });
#   $('.facets').sticky({ topSpacing: t, bottomSpacing: b + 25, getWidthFrom: '#sticky-width', responsiveWidth: true });
#
#   $(window)
#     .on('resize scroll', function() {
#       var maxHeight = $(window).height() - t - 40;
#       if ($('#mask').is(':visible')) {
#         // Nothing
#       } else {
#         $('.facets').css('height', maxHeight);
#       }
#       $('#appinfo_hover').popover('hide');
#     })
#     .on('resize', function() {
#       $('.facets').sticky('update');
#       $('nav#good').sticky({ topSpacing: window.innerWidth > 767 ? navbarHeight : 0, className: 'stuck' });
#       $('nav#good').sticky('update');
#     });
#
#   $('nav#good a[data-toggle="tab"]')
#     .on('click', function(e) {
#       if ($(e.target).data('tab')) {
#         location.hash = $(e.target).data('tab');
#       }
#     })
#     .on('shown.bs.tab', function (e) {
#       var target = this.href.substring(this.href.indexOf('#'));
#       $('.nav-links a' + target + '_tab').tab('show');
#       $('html, body').animate({ scrollTop: 0 }, 0);
#       $('.facets').sticky('update');
#       $('.mobile_nav').each(function() {
#         $(this).removeClass('visible-sm visible-xs').addClass('hidden-lg hidden-md hidden-sm hidden-xs');
#       });
#       $($(this).data('tab') + '_nav').addClass('visible-sm visible-xs').removeClass('hidden-lg hidden-md hidden-sm hidden-xs').insertBefore($('a.navbar-brand'))
#
#       $('title').text($(this).data('title'));
#       $('h1').text($(this).data('page-header'));
#       ga('send', 'pageview', location.pathname + location.search + location.hash);
#     });
#
#   if(window.location.hash) {
#     target = window.location.hash;
#     if (target === '#apps' || target === '#sitemap' || target === '#getrank' || target === '#research' || target === '#guide') {
#       $('a[data-tab="' + target + '"]').tab('show');
#     }
#   }
#
#   $('.facets').css('height', 'auto');
#
#   // Show mobile navigation left pane
#   $('a.expand_nav').on('click', function(e) {
#     e.preventDefault();
#     ga('send', 'event', 'ua_click', 'ua_hamburger', 'ua_serp_header');
#     var tab_name = $(this).data('tab-id');
#     $('.facets').sticky('unstick');
#     var $pageNav = $('#' + tab_name + ' .page_navigation');
#     if(!$pageNav.length) {
#       $pageNav = $('#default-nav .page_navigation');
#     } else if(!$pageNav.find('.facets').hasClass('default-nav-added')) {
#       $pageNav.find('.facets')
#               .addClass('default-nav-added')
#               .append('<hr>')
#               .append($('#default-nav .page_navigation .facets > *'));
#     }
#     $pageNav.removeClass('hidden-sm').removeClass('hidden-xs').show();
#     var h = $(window).height();
#     $pageNav.attr('style', 'background:#fff;position:fixed;height:' + h +'px;width:250px;overflow-y:auto;top:0;left:0;bottom:0;z-index:9999999;margin:0;padding:0');
#     $('#mask').show();
#     $('body').css('overflow', 'hidden');
#   });
#
#   // Hide mobile left navigation pane when anything inside is clicked
#   $('.facets').on('click', function() {
#     if ($('#mask').is(':visible')) {
#       $('.page_navigation').addClass('hidden-sm').addClass('hidden-xs').hide();
#       $('body').css('overflow', 'auto');
#       $('#mask').hide();
#     }
#   });
#
#   $('#mask').on('click', function(e) {
#     $('.page_navigation').addClass('hidden-sm').addClass('hidden-xs').hide();
#     $('body').css('overflow', 'auto');
#     $(this).hide();
#   });
#
#   $(document).keyup(function(e) {
#     if ($('#mask').is(':visible')) {
#       $('.page_navigation').addClass('hidden-sm').addClass('hidden-xs').hide();
#       $('body').css('overflow', 'auto');
#       $('#mask').hide();
#     }
#   });
#
#   $('#appinfo_hover').popover({
#     html: true,
#     trigger: 'manual',
#     container: $(this).attr('id'),
#     placement: 'bottom',
#     template: '<div class="popover app-info-popover" role="tooltip"><div class="arrow"></div><h3 class="popover-title"></h3><div class="popover-content"></div></div>',
#     content: function() {
#       return $('#dropdown-nav').html();
#     }
#   }).on("mouseenter", function () {
#     var _this = this;
#     $(this).popover("show");
#     $(".popover").on("mouseleave", function () {
#       $(_this).popover('hide');
#     });
#   }).on("mouseleave", function () {
#     var _this = this;
#     setTimeout(function () {
#       if (!$(".popover:hover").length) {
#         $(_this).popover("hide")
#       }
#     }, 100);
#   });
#
#   $('#mobile-search-icon').click(function() {
#     $('#mobile-search-overlay').removeClass('hidden');
#     $('#mobile-search-overlay input:visible').focus();
#   });
#
#   $('#mobile-search-overlay').click(function(e) {
#     if (e.target !== e.currentTarget) return;
#     $('#mobile-search-overlay').addClass('hidden');
#   });
#
#   $('#mobile-search-back').click(function(e) {
#     e.preventDefault();
#     $('#mobile-search-overlay').addClass('hidden');
#   });
#
#   $('#mobile-search-clear').click(function(e) {
#     $('#mobile-search').typeahead('val', '')
#                        .focus();
#   });
#
#   if("SE" === "FR" || "SE" === "DE") {
#     hj('trigger', "getapp_international_se");
#   }
#
# });
#   </script>
#   <script>
#    function xsListingBookmarkSet(listingId, associationType) {
#   var $bookmark = $('.xs-listing-bookmark[data-listing-id="' + listingId + '"]');
#   if(associationType == 'save') {
#     $bookmark.addClass('active');
#   } else {
#     $bookmark.removeClass('active');
#   }
# }
#
# function xsListingBookmarkSuccess(data, textStatus, jqXHR) {
#   if(data.authorized) {
#     xsListingBookmarkSet(this, data.associationType);
#   } else {
#     (new LoginModal({source: 'serp/save', onboarding: true})).render();
#   }
# }
#
# domready(function() {
#   $('.xs-listing-bookmark').click(function($event) {
#     $event.preventDefault();
#     var $this = $(this)
#       , listingId = $this.data('listing-id')
#       , isActive = $this.hasClass('active')
#       , newState = isActive ? '0' : '1';
#
#     $.ajax({
#       method: 'PUT',
#       url: '/community/save/' + listingId + '/' + newState,
#       dataType: 'json',
#       success: xsListingBookmarkSuccess,
#       context: listingId
#     });
#
#     ga('send', 'event', 'ua_click_save', 'ua_toggle', "serp_header");
#   });
# });
#   </script>
#   <!-- timing
# ["sequel","SELECT",null,2]
# ["solr_time","Marketplace","serps:424",87]
# ["solr_time","Marketplace","serps:550",5]
# ["solr_time","footer_headers","base_controller:1238",3]
# ["solr_size","Marketplace","serps:424",1342926]
# ["solr_size","Marketplace","serps:550",520]
# ["solr_size","footer_headers","base_controller:1238",921]
# ["solr_qtime","Marketplace","serps:424",17]
# ["solr_qtime","Marketplace","serps:550",0]
# ["solr_qtime","footer_headers","base_controller:1238",1]
# ["controller","serp_header",null,116]
# ["template","serp_header","serp/content_exp/_business_intelligence_analytics_summary",0]
# ["template","serp_header","facets/_checkbox_slug",1]
# ["template","serp_header","facets/_text_link",0]
# ["template","serp_header","facets/_checkbox",5]
# ["template","serp_header","profile/_company_size_select",0]
# ["template","serp_header","profile/_company_industry_select",0]
# ["template","serp_header","profile/_modal",1]
# ["template","serp_header","facets/_form_links",8]
# ["template","serp_header","serp/_current_selection",0]
# ["template","serp_header","| &nbsp;\na.serp-read-more href=url Read more about #{name}",1]
# ["template","serp_header","serp/_recommendation_score",2]
# ["template","serp_header","serp/_toggle",2]
# ["template","serp_header","serp/_community",3]
# ["template","serp_header","serp/_listing",14]
# ["template","serp_header","cards/_mobile",7]
# ["template","serp_header","serp/content_exp/_business_intelligence_analytics",0]
# ["template","serp_header","layout/_new_relic",0]
# ["template","serp_header","layout/_gapct",0]
# ["template","serp_header","layout/_analytics_head",0]
# ["template","serp_header","layout/_tag_manager_body",0]
# -->
#   <script type="text/javascript">
#    domready(function() {
#   $(document).ajaxSend(function(event, xhr, settings){
#     ga('send', 'pageview', settings.url);
#     dataLayer.push({
#       'event': 'VirtualPageview',
#       'virtualPageURL': settings.url
#     });
#   });
# });
#   </script>
#   <div class="modal community-modal" id="community-login-modal">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <div class="modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         <i class="fa fa-times-circle-o">
#         </i>
#        </span>
#       </button>
#       <h4 class="modal-title">
#        Sign up / Sign in
#       </h4>
#      </div>
#      <div class="modal-body">
#       <p>
#        Both new and existing users can sign in with LinkedIn.
#       </p>
#       <p>
#        <button class="btn btn-primary btn-lg community-login-modal-button evnt gtm" data-evac="ua_linkedin_callback" data-evca="ua_community_signin" data-evla="serp_header" type="button">
#         <i class="fa fa-linkedin-square">
#         </i>
#         Sign in with LinkedIn
#        </button>
#        <div class="text-muted">
#         <em>
#          This opens a popup window
#         </em>
#        </div>
#       </p>
#       <div class="paper-checkbox newsletter-optin">
#        <div class="check">
#         <i class="fa fa-check">
#         </i>
#        </div>
#        Discover new apps through GetApp’s newsletter
#       </div>
#       <div class="paper-checkbox follow-optin">
#        <div class="check">
#         <i class="fa fa-check">
#         </i>
#        </div>
#        Follow GetApp on LinkedIn
#       </div>
#       <br/>
#       <p>
#        Once you are signed in you'll be able to:
#       </p>
#       <ul>
#        <li>
#         Get personalized recommendations
#        </li>
#        <li>
#         Access exclusive content (security data, quarterly reports, …)
#        </li>
#        <li>
#         Follow apps you use
#        </li>
#        <li>
#         Rate apps
#        </li>
#        <li>
#         Write reviews
#        </li>
#        <li>
#         Bookmark apps
#        </li>
#       </ul>
#       <p id="vendor-login-text">
#        <strong>
#         Are you a Software Vendor?
#         <a href="https://www.capterra.com/vp/login?utm_source=GetApp&amp;utm_medium=referral" rel="noopener" target="_blank">
#          Sign in here
#         </a>
#        </strong>
#       </p>
#      </div>
#      <div class="modal-footer">
#       <small>
#        By proceeding, you agree to our
#        <a href="/terms_of_use" target="_blank">
#         Terms of Use
#        </a>
#        and
#        <a href="/privacy_policy" target="_blank">
#         Privacy Policy
#        </a>
#       </small>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %%
sitelist = ['https://www.getapp.com/business-intelligence-analytics-software/?page='+str(i) for i in range(0,21)]
data = []
count = 0
for site in sitelist:
    page = requests.get(site)
    soup = BeautifulSoup(page.text, "html.parser")
    names = soup.find_all('div', class_ = 'short-overview')
    count +=1
    for i in names: 
        name = i.text.strip()
        nextsite = 'https://www.getapp.com' + i.a['href']
        onepage = requests.get(nextsite)
        onesoup = BeautifulSoup(onepage.text, "html.parser")
        title = onesoup.find('a', class_ = 'premium-listing-clickout')
        data.append((title))    
df = pd.DataFrame(np.array(data))

# %%
page_num = 0
http_status_okay = True
while http_status_okay:
    page_num = page_num + 1
    time.sleep(2) #delay time requests are sent so we don't get kicked by server
    sitelist = "https://www.getapp.com/business-intelligence-analytics-software-{0}".format(i)
    page = requests.get(sitelist)
    soup = BeautifulSoup(page.text, "html.parser")    
    names = soup.find_all('div', class_ = 'short-overview')
    for i in names: 
        name = i.text.strip()
        nextsite = 'https://www.getapp.com' + i.a['href']
        onepage = requests.get(nextsite)
        onesoup = BeautifulSoup(onepage.text, "html.parser")
        title = onesoup.find('a', class_ = 'premium-listing-clickout')
        data.append((title))       
    # continue if we get a 200 response code
    if page2.status_code is 200:
        http_status_okay = True
    else:
        http_status_okay = False
df = pd.DataFrame(np.array(data))

# %%
df
# Out:
#                                                     0
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5   <a class="premium-listing-clickout" data-evac=...
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None

# %%
url = "https://www.getapp.com/security-software/a/deliveryslip/"
page = requests.get(url)
soup = BeautifulSoup(page.text,"html.parser")
names = soup.find_all('div', class_ = 'pull-left')
full_name = []
for i in names:
    name = i.text
    full_name.append(name)
print(full_name[1])
# Out:
# [u'Value for moneyFeaturesEase of useCustomer support']
